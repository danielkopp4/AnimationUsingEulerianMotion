# %%
import torch
from common.models.motion_field_estimator import get_G, get_D, GANLoss

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device("cpu")
print(device)
# Out:
# cuda

# %%
G = get_G(3,2, 64, device=device)

# %%
print(G)
# Out:
# Generator(
#   (model): Sequential(
#     (0): ReflectionPad2d((3, 3, 3, 3))
#     (1): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1))
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#     (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (11): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
#     (13): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
# ...

# %%
fake_img = torch.zeros((1, 3, 612, 1280)).to(device)

# %%
t = G(fake_img)

# %%
t.shape
# t.split(612, dim=2)[0].shape
# Out:
# torch.Size([1, 2, 612, 1280])

# %%
D = get_D(2, device=device)

# %%
t2 = D(t)

# %%
t2[0][0].device
# Out:
# device(type='cuda', index=0)

# %%
loss = GANLoss(device=device).to(device)

# %%
loss(t2, False)
# Out:
# cuda:0 pred
# cuda:0 tt
# tensor(1.1340, device='cuda:0', grad_fn=<AddBackward0>)

# %%
D.state_dict()
# Out:
# OrderedDict([('layer0.0.weight',
#               tensor([[[[ 1.2616e-02,  1.2316e-02, -3.6994e-03, -1.2390e-02],
#                         [ 1.8252e-02, -1.1396e-02, -1.8750e-02, -1.6596e-02],
#                         [-1.7102e-02, -1.2588e-02, -3.0074e-02, -3.0856e-02],
#                         [-4.7912e-03,  1.0688e-02,  1.6237e-02,  3.1859e-03]],
#
#                        [[-9.4015e-03,  2.9287e-02, -2.8304e-03, -3.3651e-02],
#                         [-2.1043e-02, -1.6861e-04,  8.0093e-03, -2.1205e-02],
#                         [-2.5078e-02, -1.8023e-02,  3.8180e-02,  1.3343e-02],
#                         [-1.0581e-02,  2.2830e-03,  2.6981e-02, -5.2565e-02]]],
#
#
#                       [[[ 5.0453e-02,  1.8827e-02, -1.6160e-02,  5.1825e-02],
#                         [-2.8443e-02, -5.9336e-03, -4.3045e-02, -2.1477e-02],
#                         [-5.3445e-04,  4.9283e-03, -2.9998e-02,  3.2527e-03],
# ...
